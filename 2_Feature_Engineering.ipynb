# %% [markdown]
# # Feature Engineering

# %%
#load package
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px
import warnings
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score,confusion_matrix

# %%
# Set pandas option to display all columns
pd.set_option('display.max_columns', None)

# %%
# Load the Parquet file into a DataFrame
df = pd.read_parquet('transaction_no_duplicate.parquet')

# %%
df
# Out:
#         accountNumber  customerId  creditLimit  availableMoney  \
# 0           737265056   737265056         5000         5000.00
# 1           737265056   737265056         5000         5000.00
# 2           737265056   737265056         5000         5000.00
# 3           737265056   737265056         5000         5000.00
# 4           830329091   830329091         5000         5000.00
# ...               ...         ...          ...             ...
# 786358      732852505   732852505        50000        48904.96
# 786359      732852505   732852505        50000        48785.04
# 786360      732852505   732852505        50000        48766.15
# 786361      732852505   732852505        50000        48716.72
# 786362      732852505   732852505        50000        48666.83
#
#        transactionDateTime  transactionAmount         merchantName acqCountry  \
# 0      2016-08-13 14:27:32              98.55                 Uber         US
# 1      2016-10-11 05:05:54              74.51          AMC #191138         US
# 2      2016-11-08 09:18:39               7.47           Play Store         US
# 3      2016-12-10 02:14:50               7.47           Play Store         US
# 4      2016-03-24 21:04:46              71.18  Tim Hortons #947751         US
# ...                    ...                ...                  ...        ...
# 786358 2016-12-22 18:44:12             119.92                 Lyft         US
# 786359 2016-12-25 16:20:34              18.89             hulu.com         US
# 786360 2016-12-27 15:46:24              49.43                 Lyft         US
# 786361 2016-12-29 00:30:55              49.89          walmart.com         US
# 786362 2016-12-30 20:10:29              72.18                 Uber         US
#
#        merchantCountryCode posEntryMode posConditionCode  \
# 0                       US           02               01
# 1                       US           09               01
# 2                       US           09               01
# 3                       US           09               01
# 4                       US           02               01
# ...                    ...          ...              ...
# 786358                  US           90               01
# 786359                  US           09               01
# 786360                  US           02               01
# 786361                  US           09               99
# 786362                  US           05               01
#
#         merchantCategoryCode currentExpDate accountOpenDate  \
# 0                  rideshare     2023-06-01      2015-03-14
# 1              entertainment     2024-02-01      2015-03-14
# 2                 mobileapps     2025-08-01      2015-03-14
# 3                 mobileapps     2025-08-01      2015-03-14
# 4                   fastfood     2029-10-01      2015-08-06
# ...                      ...            ...             ...
# 786358             rideshare     2022-12-01      2012-08-23
# 786359  online_subscriptions     2023-08-01      2012-08-23
# 786360             rideshare     2025-08-01      2012-08-23
# 786361         online_retail     2022-07-01      2012-08-23
# 786362             rideshare     2024-05-01      2012-08-23
#
#        dateOfLastAddressChange  cardCVV  enteredCVV  cardLast4Digits  \
# 0                   2015-03-14      414         414             1803
# 1                   2015-03-14      486         486              767
# 2                   2015-03-14      486         486              767
# 3                   2015-03-14      486         486              767
# 4                   2015-08-06      885         885             3143
# ...                        ...      ...         ...              ...
# 786358              2012-08-23      936         936             3783
# 786359              2012-08-23      939         939             3388
# 786360              2012-08-23      936         936             3783
# 786361              2012-08-23      939         939             3388
# 786362              2012-08-23      939         939             3388
#
#        transactionType  currentBalance  cardPresent  expirationDateKeyInMatch  \
# 0             PURCHASE            0.00        False                     False
# 1             PURCHASE            0.00         True                     False
# 2             PURCHASE            0.00        False                     False
# 3             PURCHASE            0.00        False                     False
# 4             PURCHASE            0.00         True                     False
# ...                ...             ...          ...                       ...
# 786358        PURCHASE         1095.04        False                     False
# 786359        PURCHASE         1214.96        False                     False
# 786360        PURCHASE         1233.85        False                     False
# 786361        PURCHASE         1283.28        False                     False
# 786362        PURCHASE         1333.17        False                     False
#
#         isFraud
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 786358    False
# 786359    False
# 786360    False
# 786361    False
# 786362    False
#
# [740001 rows x 23 columns]

# %%
# check the shape(we start from the transaction without duplicates so the len is reduced)
"Dataset Dimensions: {}x{}".format(df.shape[0], df.shape[1])
# Out:
# 'Dataset Dimensions: 740001x23'

# %%
# check the null(we have already removed fully null columns in previous steps)
df.isnull().sum()
# Out:
# accountNumber                  0
# customerId                     0
# creditLimit                    0
# availableMoney                 0
# transactionDateTime            0
# transactionAmount              0
# merchantName                   0
# acqCountry                  4289
# merchantCountryCode          686
# posEntryMode                3814
# posConditionCode             383
# merchantCategoryCode           0
# currentExpDate                 0
# accountOpenDate                0
# dateOfLastAddressChange        0
# cardCVV                        0
# enteredCVV                     0
# cardLast4Digits                0
# transactionType              680
# currentBalance                 0
# cardPresent                    0
# expirationDateKeyInMatch       0
# isFraud                        0
# dtype: int64

# %%
# Replace missing values with 'Missing' for all specified columns
columns_to_fill_with_missing = ['acqCountry', 'posEntryMode', 'merchantCountryCode', 'transactionType', 'posConditionCode']

for column in columns_to_fill_with_missing:
    df[column] = df[column].fillna('Missing')

# %% [markdown]
# # Drop Columns

# %% [markdown]
# **accountNumber and customerId are 1:1 match. We can drop one.**

# %%
df = df.drop(["accountNumber"],axis=1)

# %% [markdown]
# **generate a matchCVV when Card CVV = entered CVV**

# %%
df["matchCVV"] = df.cardCVV == df.enteredCVV

# %%
df = df.drop(["cardCVV", "enteredCVV"],axis=1)

# %% [markdown]
# # Add New Features

# %% [markdown]
# To prevent data leakage, we use solely historical data to build relevant features, particularly those related to fraud history.

# %% [markdown]
# # Time related Features

# %% [markdown]
# ## Age of account

# %%
# Calculate the difference in days between transactionDateTime and accountOpenDate
df["accountAge"] = (df.transactionDateTime - df.accountOpenDate).dt.days

# %% [markdown]
# ## Time since address was changed

# %%
# Calculate the difference in days between transactionDateTime and dateOfLastAddressChange
df["sinceDateOfLastAddressChange"] = (
    df.transactionDateTime - df.dateOfLastAddressChange
).dt.days

# %% [markdown]
# ## Months between currentExpDate and transactionDateTime

# %%
# Calculate the difference in months between currentExpDate and transactionDateTime
df['monthsToExpiration'] = ((df['currentExpDate'].dt.year - df['transactionDateTime'].dt.year) * 12 + 
                            (df['currentExpDate'].dt.month - df['transactionDateTime'].dt.month))

# %% [markdown]
# ## General date properties

# %%
# Extract useful time-related features
df['transactionMonth'] = df['transactionDateTime'].dt.month
df['transactionDay'] = df['transactionDateTime'].dt.day
df['transactionHour'] = df['transactionDateTime'].dt.hour
df['transactionWeekday'] = df['transactionDateTime'].dt.weekday

# %% [markdown]
# ## Morning, afternoon, evening, night

# %%
# morning, afternoon, evening, night
def time_of_day(hour):
    if 6 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 18:
        return "Afternoon"
    elif 18 <= hour < 24:
        return "Evening"
    else:
        return "Night"

df['time_of_day'] = df['transactionHour'].apply(time_of_day)

# %% [markdown]
# ## Peak Hours

# %%
# Modify the 'is_peak_hour' calculation to return True or False
df['is_peak_hour'] = df['transactionHour'].apply(lambda x: True if 9 <= x <= 18 else False)

# %% [markdown]
# ## Weekday or Weekend

# %%
# Flag weekend transactions (5=Saturday, 6=Sunday)
df['is_weekend'] = df['transactionWeekday'].apply(lambda x: True if x >= 5 else False)

# %% [markdown]
# ## Time Since Last Transaction

# %%
# Calculate the time difference between consecutive transactions for the same
df = df.sort_values(by=['customerId', 'transactionDateTime'])
df['transaction_time_diff'] = df.groupby('customerId')['transactionDateTime'].diff().dt.total_seconds()

# Replace missing values in 'transaction_rolling_diff' with the mean of the customer's rolling diff
df['transaction_time_diff'] = df.groupby('customerId')['transaction_time_diff'].transform(
    lambda x: x.fillna(x.mean())
)

df['transaction_time_diff'] = df['transaction_time_diff'].transform(
    lambda x: x.fillna(x.mean())
)

# %% [markdown]
# ## Minimum time (minutes) between transactions in a 30 day span

# %%
df["min_time_diff_month"] = (
    df.groupby("customerId")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transaction_time_diff"].min())
    .reset_index("customerId")
    .drop("customerId", axis=1)
    .sort_index()
    .squeeze()
)

# %% [markdown]
# # Customer related Features

# %% [markdown]
# ## Historical Average fraud of customer(moving average)

# %% [markdown]
# By utilizing the shift() function, the code ensures that the current transaction's "isFraud" value is excluded from the rolling average calculation.

# %%
df["avgFraud"] = (
    df.groupby("customerId")["isFraud"]
    .apply(lambda x: x.shift().expanding().mean())
    .reset_index(level=0, drop=True)  # Reset the index to match the DataFrame
    .fillna(0)  # Replace NaN values with 0
)

# %% [markdown]
# ## Fraud History Flag

# %%
# Create a flag that marks all records after the first fraud occurrence for each customer as True
df['customer_fraud_flag'] = df.groupby('customerId')['isFraud'].transform(lambda x: x.cumsum().shift(fill_value=0) > 0)

# %% [markdown]
# ## Customer Transaction Amount Features

# %%
# Normalize the transactionAmount by the creditLimit or availableMoney to understand its relative significance.
df['relative_amount'] = df['transactionAmount'] / df['creditLimit']

# %% [markdown]
# ## Customer Transaction Statistics Engineering( moving average over 1 month)

# %%
# Sort the data by customerId and transactionDateTime
df = df.sort_values(['customerId', 'transactionDateTime'])

# Calculate rolling min, max, mean, and std over a 30-day window
df["rolling_min_month"] = (
    df.groupby("customerId")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].min())
    .reset_index("customerId")
    .drop("customerId", axis=1)
    .sort_index()
    .squeeze()
)

df["rolling_max_month"] = (
    df.groupby("customerId")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].max())
    .reset_index("customerId")
    .drop("customerId", axis=1)
    .sort_index()
    .squeeze()
)

df["rolling_mean_month"] = (
    df.groupby("customerId")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].mean())
    .reset_index("customerId")
    .drop("customerId", axis=1)
    .sort_index()
    .squeeze()
)

df["rolling_std_month"] = (
    df.groupby("customerId")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].std())
    .reset_index("customerId")
    .drop("customerId", axis=1)
    .sort_index()
    .squeeze()
)

# Calculate the rolling difference (diff)
df['transaction_rolling_diff'] = df.groupby('customerId')['transactionAmount'].diff()

# Replace missing values in 'transaction_expanding_std' with the mean of the customer's expanding std
df['rolling_std_month'] = df.groupby('customerId')['rolling_std_month'].transform(
    lambda x: x.fillna(x.mean())
)

# Replace missing values in 'transaction_expanding_std' with the mean of the customer's expanding std
df['rolling_std_month'] = df['rolling_std_month'].transform(
    lambda x: x.fillna(x.mean())
)

# Replace missing values in 'transaction_rolling_diff' with the mean of the customer's rolling diff
df['transaction_rolling_diff'] = df.groupby('customerId')['transaction_rolling_diff'].transform(
    lambda x: x.fillna(x.mean())
)

df['transaction_rolling_diff'] = df['transaction_rolling_diff'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
# Verify the new features
df[['customerId', 'transactionDateTime', 'transactionAmount', 'rolling_min_month', 
    'rolling_max_month', 'rolling_mean_month', 'rolling_std_month', 'transaction_rolling_diff']].head()
# Out:
#         customerId transactionDateTime  transactionAmount  rolling_min_month  \
# 541900   100088067 2016-01-12 00:59:52             205.13             205.13
# 541901   100088067 2016-01-12 19:49:41              46.43              46.43
# 541902   100088067 2016-01-17 15:41:46             378.67              46.43
# 541903   100088067 2016-02-02 19:57:18              66.07              46.43
# 541904   100088067 2016-02-03 04:48:54             141.60              46.43
#
#         rolling_max_month  rolling_mean_month  rolling_std_month  \
# 541900             205.13          205.130000         103.548830
# 541901             205.13          125.780000         112.217846
# 541902             378.67          210.076667         166.175228
# 541903             378.67          174.075000         153.603226
# 541904             378.67          167.580000         133.814754
#
#         transaction_rolling_diff
# 541900                 -2.745775
# 541901               -158.700000
# 541902                332.240000
# 541903               -312.600000
# 541904                 75.530000

# %% [markdown]
# ## Customer Transaction Outliers

# %%
#Flag transactions with amounts far from the customer’s usual range.
df['is_outlier_customer'] = (df['transactionAmount'] < (df['rolling_mean_month'] - 3 * df['rolling_std_month'])) | \
                   (df['transactionAmount'] > (df['rolling_mean_month'] + 3 * df['rolling_std_month']))

# %% [markdown]
# # Merchant related Features

# %% [markdown]
# ## Merchant Statistics(moving average over 1 month)

# %%
# Sort the data by merchantName and transactionDateTime
df = df.sort_values(['merchantName', 'transactionDateTime'])

# Calculate rolling min, max, mean, and std over a 30-day window for each merchant
df["merchant_rolling_min_month"] = (
    df.groupby("merchantName")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].min())
    .reset_index("merchantName")
    .drop("merchantName", axis=1)
    .sort_index()
    .squeeze()
)

df["merchant_rolling_max_month"] = (
    df.groupby("merchantName")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].max())
    .reset_index("merchantName")
    .drop("merchantName", axis=1)
    .sort_index()
    .squeeze()
)

df["merchant_rolling_mean_month"] = (
    df.groupby("merchantName")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].mean())
    .reset_index("merchantName")
    .drop("merchantName", axis=1)
    .sort_index()
    .squeeze()
)

df["merchant_rolling_std_month"] = (
    df.groupby("merchantName")
    .apply(lambda x: x.rolling("30D", on="transactionDateTime")["transactionAmount"].std())
    .reset_index("merchantName")
    .drop("merchantName", axis=1)
    .sort_index()
    .squeeze()
)

# Calculate the rolling difference (diff) for each merchant
df['merchant_transaction_rolling_diff'] = df.groupby('merchantName')['transactionAmount'].diff()

# Replace missing values in rolling std and rolling diff for merchants
df['merchant_rolling_std_month'] = df.groupby('merchantName')['merchant_rolling_std_month'].transform(
    lambda x: x.fillna(x.mean())
)

df['merchant_rolling_std_month'] = df['merchant_rolling_std_month'].transform(
    lambda x: x.fillna(x.mean())
)

df['merchant_transaction_rolling_diff'] = df.groupby('merchantName')['merchant_transaction_rolling_diff'].transform(
    lambda x: x.fillna(x.mean())
)

df['merchant_transaction_rolling_diff'] = df['merchant_transaction_rolling_diff'].transform(
    lambda x: x.fillna(x.mean())
)

# Verify the new features
df[['merchantName', 'transactionDateTime', 'transactionAmount', 'merchant_rolling_min_month', 
    'merchant_rolling_max_month', 'merchant_rolling_mean_month', 'merchant_rolling_std_month', 
    'merchant_transaction_rolling_diff']].head()
# Out:
#        merchantName transactionDateTime  transactionAmount  \
# 530787      1st BBQ 2016-01-01 01:56:16              78.91
# 182990      1st BBQ 2016-01-01 03:50:57             378.92
# 479512      1st BBQ 2016-01-01 18:46:43               2.42
# 416551      1st BBQ 2016-01-01 19:23:12             134.84
# 297574      1st BBQ 2016-01-01 22:23:06             128.21
#
#         merchant_rolling_min_month  merchant_rolling_max_month  \
# 530787                       78.91                       78.91
# 182990                       78.91                      378.92
# 479512                        2.42                      378.92
# 416551                        2.42                      378.92
# 297574                        2.42                      378.92
#
#         merchant_rolling_mean_month  merchant_rolling_std_month  \
# 530787                    78.910000                  150.270168
# 182990                   228.915000                  212.139105
# 479512                   153.416667                  199.001244
# 416551                   148.772500                  162.749101
# 297574                   144.660000                  141.244524
#
#         merchant_transaction_rolling_diff
# 530787                           0.210786
# 182990                         300.010000
# 479512                        -376.500000
# 416551                         132.420000
# 297574                          -6.630000

# %% [markdown]
# ## Merchant outlier transaction

# %%
#Flag transactions with amounts far from the Merchant’s usual range.
df['is_outlier_merchant'] = (df['transactionAmount'] < (df['merchant_rolling_mean_month'] - 3 * df['merchant_rolling_std_month'])) | \
                   (df['transactionAmount'] > (df['merchant_rolling_mean_month'] + 3 * df['merchant_rolling_std_month']))

# %% [markdown]
# ## Merchant Fraud(moving average)

# %% [markdown]
# By utilizing the shift() function, the code ensures that the current transaction's "isFraud" value is excluded from the rolling average calculation.

# %%
# Calculate the average fraud rate (avgFraud) for each customerId
df["MerchantavgFraud"] = (
    df.groupby("merchantName")["isFraud"]
    .apply(lambda x: x.shift().expanding().mean())
    .reset_index(level=0, drop=True)  # Reset the index to match the original DataFrame
    .fillna(0)  # Replace NaN values with 0
)

# %% [markdown]
# ## Merchant Popularity

# %%
#Count the number of transactions per merchant.
df['merchant_transaction_count'] = df.groupby('merchantName')['transactionAmount'].transform('count')

# %% [markdown]
# ## Merchant Diversity

# %%
#Count the number of unique merchants a customer interacts with.

df['unique_merchants'] = df.groupby('customerId')['merchantName'].transform('nunique')

# %% [markdown]
# # Other Features

# %% [markdown]
# ## Customer-Merchant Pair Frequency

# %%
# Count the number of interactions between each customer and merchant.
df['customer_merchant_count'] = df.groupby(['customerId', 'merchantName'])['transactionAmount'].transform('count')

# %% [markdown]
# ## Rare Interaction

# %%
#Flag transactions with merchants that a customer rarely interacts with.
df['rare_interaction'] = df['customer_merchant_count'] < 2

# %% [markdown]
# ## Missing value feature

# %% [markdown]
# **I believe that the missing values in acqCountry, posEntryMode, merchantCountryCode, transactionType, and posConditionCode might contain information related to fraud.**

# %%
# Create a new feature to flag if any of the specified columns have the value "Missing"
columns_to_check = ['acqCountry', 'posEntryMode', 'merchantCountryCode', 'transactionType', 'posConditionCode']

# Create a new feature to flag if any of the specified columns have the value "Missing" as boolean
df['is_missing_flag'] = df[columns_to_check].apply(lambda row: any(value == "Missing" for value in row), axis=1)

# %%
df
# Out:
#         customerId  creditLimit  availableMoney transactionDateTime  \
# 530787   332699562         7500         7500.00 2016-01-01 01:56:16
# 182990   248663206         5000         5000.00 2016-01-01 03:50:57
# 479512   302778428        10000        10000.00 2016-01-01 18:46:43
# 416551   568638109        50000        50000.00 2016-01-01 19:23:12
# 297574   747568560        10000         9985.71 2016-01-01 22:23:06
# ...            ...          ...             ...                 ...
# 778053   198092241         7500         2811.33 2016-12-26 21:55:07
# 608159   599847715         2500         1000.34 2016-12-27 02:16:57
# 608162   599847715         2500          844.56 2016-12-27 06:48:55
# 13223    393869032        15000         6188.68 2016-12-27 19:21:15
# 750392   405648828         7500         2087.12 2016-12-29 02:15:06
#
#         transactionAmount        merchantName acqCountry merchantCountryCode  \
# 530787              78.91             1st BBQ         US                  US
# 182990             378.92             1st BBQ         US                  US
# 479512               2.42             1st BBQ         US                  US
# 416551             134.84             1st BBQ         US                  US
# 297574             128.21             1st BBQ         US                  US
# ...                   ...                 ...        ...                 ...
# 778053               5.80  williamssonoma.com         US                  US
# 608159               0.00  williamssonoma.com         US                  US
# 608162              27.41  williamssonoma.com         US                  US
# 13223               67.62  williamssonoma.com         US                  US
# 750392             438.50  williamssonoma.com         US                  US
#
#        posEntryMode posConditionCode merchantCategoryCode currentExpDate  \
# 530787           09               01                 food     2026-09-01
# 182990           05               08                 food     2026-08-01
# 479512           05               08                 food     2028-11-01
# 416551           05               08                 food     2022-03-01
# 297574           02               01                 food     2030-06-01
# ...             ...              ...                  ...            ...
# 778053           05               01            furniture     2029-10-01
# 608159           80               01            furniture     2023-06-01
# 608162           02               01            furniture     2020-11-01
# 13223            05               08            furniture     2032-10-01
# 750392           02               01            furniture     2025-01-01
#
#        accountOpenDate dateOfLastAddressChange  cardLast4Digits  \
# 530787      2015-05-14              2015-05-14             3271
# 182990      2013-05-27              2013-05-27             5485
# 479512      2013-10-08              2013-10-08             7370
# 416551      2014-12-22              2014-12-22             4685
# 297574      2015-07-08              2015-07-08             1300
# ...                ...                     ...              ...
# 778053      2014-12-14              2016-12-02             3156
# 608159      2014-04-03              2016-12-21             9104
# 608162      2014-04-03              2016-12-21             9104
# 13223       2011-05-14              2016-04-18             3261
# 750392      2013-01-15              2016-10-15             9454
#
#              transactionType  currentBalance  cardPresent  \
# 530787              PURCHASE            0.00         True
# 182990              PURCHASE            0.00         True
# 479512              PURCHASE            0.00         True
# 416551              PURCHASE            0.00         True
# 297574              PURCHASE           14.29         True
# ...                      ...             ...          ...
# 778053              PURCHASE         4688.67         True
# 608159  ADDRESS_VERIFICATION         1499.66        False
# 608162              PURCHASE         1655.44         True
# 13223               PURCHASE         8811.32         True
# 750392              PURCHASE         5412.88         True
#
#         expirationDateKeyInMatch  isFraud  matchCVV  accountAge  \
# 530787                     False    False      True         232
# 182990                     False    False      True         949
# 479512                     False    False      True         815
# 416551                     False    False      True         375
# 297574                     False    False      True         177
# ...                          ...      ...       ...         ...
# 778053                     False    False      True         743
# 608159                     False    False      True         999
# 608162                     False    False      True         999
# 13223                      False    False      True        2054
# 750392                     False    False      True        1444
#
#         sinceDateOfLastAddressChange  monthsToExpiration  transactionMonth  \
# 530787                           232                 128                 1
# 182990                           949                 127                 1
# 479512                           815                 154                 1
# 416551                           375                  74                 1
# 297574                           177                 173                 1
# ...                              ...                 ...               ...
# 778053                            24                 154                12
# 608159                             6                  78                12
# 608162                             6                  47                12
# 13223                            253                 190                12
# 750392                            75                  97                12
#
#         transactionDay  transactionHour  transactionWeekday time_of_day  \
# 530787               1                1                   4       Night
# 182990               1                3                   4       Night
# 479512               1               18                   4     Evening
# 416551               1               19                   4     Evening
# 297574               1               22                   4     Evening
# ...                ...              ...                 ...         ...
# 778053              26               21                   0     Evening
# 608159              27                2                   1       Night
# 608162              27                6                   1     Morning
# 13223               27               19                   1     Evening
# 750392              29                2                   3       Night
#
#         is_peak_hour  is_weekend  transaction_time_diff  min_time_diff_month  \
# 530787         False       False          563305.800000        563305.800000
# 182990         False       False           15786.712425         15786.712425
# 479512          True       False          587404.886792        587404.886792
# 416551         False       False          617382.380000        617382.380000
# 297574         False       False            6278.000000          6278.000000
# ...              ...         ...                    ...                  ...
# 778053         False       False           40382.000000            84.000000
# 608159         False       False           21783.000000            53.000000
# 608162         False       False            6001.000000            53.000000
# 13223          False       False          181978.000000          2689.000000
# 750392         False       False           28697.000000          1159.000000
#
#         avgFraud  customer_fraud_flag  relative_amount  rolling_min_month  \
# 530787  0.000000                False         0.010521              78.91
# 182990  0.000000                False         0.075784             378.92
# 479512  0.000000                False         0.000242               2.42
# 416551  0.000000                False         0.002697             134.84
# 297574  0.000000                False         0.012821              14.29
# ...          ...                  ...              ...                ...
# 778053  0.012188                 True         0.000773               0.00
# 608159  0.010343                 True         0.000000               0.00
# 608162  0.010323                 True         0.010964               0.00
# 13223   0.021277                 True         0.004508               5.17
# 750392  0.048611                 True         0.058467               0.26
#
#         rolling_max_month  rolling_mean_month  rolling_std_month  \
# 530787              78.91           78.910000         123.686859
# 182990             378.92          378.920000         141.922028
# 479512               2.42            2.420000         132.489609
# 416551             134.84          134.840000         116.196776
# 297574             128.21           71.250000          80.553605
# ...                   ...                 ...                ...
# 778053             806.32          122.153974         126.488999
# 608159            1470.26          164.640935         199.883869
# 608162            1470.26          163.061560         198.969898
# 13223              222.01           88.400000          79.579252
# 750392             438.50          132.156061         109.088413
#
#         transaction_rolling_diff  is_outlier_customer  \
# 530787                 -0.041455                False
# 182990                 -0.137039                False
# 479512                  0.665094                False
# 416551                 -1.201000                False
# 297574                113.920000                False
# ...                          ...                  ...
# 778053                -59.070000                False
# 608159               -723.030000                False
# 608162                -11.170000                False
# 13223                 -64.570000                False
# 750392                402.820000                False
#
#         merchant_rolling_min_month  merchant_rolling_max_month  \
# 530787                       78.91                       78.91
# 182990                       78.91                      378.92
# 479512                        2.42                      378.92
# 416551                        2.42                      378.92
# 297574                        2.42                      378.92
# ...                            ...                         ...
# 778053                        0.00                      639.92
# 608159                        0.00                      639.92
# 608162                        0.00                      639.92
# 13223                         0.00                      639.92
# 750392                        0.00                      639.92
#
#         merchant_rolling_mean_month  merchant_rolling_std_month  \
# 530787                    78.910000                  150.270168
# 182990                   228.915000                  212.139105
# 479512                   153.416667                  199.001244
# 416551                   148.772500                  162.749101
# 297574                   144.660000                  141.244524
# ...                             ...                         ...
# 778053                   131.321892                  148.001549
# 608159                   127.866053                  147.533974
# 608162                   118.812632                  142.658222
# 13223                    119.615676                  143.401419
# 750392                   127.673514                  152.675886
#
#         merchant_transaction_rolling_diff  is_outlier_merchant  \
# 530787                           0.210786                False
# 182990                         300.010000                False
# 479512                        -376.500000                False
# 416551                         132.420000                False
# 297574                          -6.630000                False
# ...                                   ...                  ...
# 778053                         -35.690000                False
# 608159                          -5.800000                False
# 608162                          27.410000                False
# 13223                           40.210000                False
# 750392                         370.880000                False
#
#         MerchantavgFraud  merchant_transaction_count  unique_merchants  \
# 530787          0.000000                         777                29
# 182990          0.000000                         777               475
# 479512          0.000000                         777                47
# 416551          0.000000                         777                40
# 297574          0.000000                         777               192
# ...                  ...                         ...               ...
# 778053          0.004255                         475                52
# 608159          0.004246                         475                71
# 608162          0.004237                         475                71
# 13223           0.004228                         475                39
# 750392          0.004219                         475                22
#
#         customer_merchant_count  rare_interaction  is_missing_flag
# 530787                        1              True            False
# 182990                       10             False            False
# 479512                        2             False            False
# 416551                        1              True            False
# 297574                        1              True            False
# ...                         ...               ...              ...
# 778053                      126             False            False
# 608159                       52             False            False
# 608162                       52             False            False
# 13223                         9             False            False
# 750392                       16             False            False
#
# [740001 rows x 54 columns]

# %%
df.isnull().sum()
# Out:
# customerId                           0
# creditLimit                          0
# availableMoney                       0
# transactionDateTime                  0
# transactionAmount                    0
# merchantName                         0
# acqCountry                           0
# merchantCountryCode                  0
# posEntryMode                         0
# posConditionCode                     0
# merchantCategoryCode                 0
# currentExpDate                       0
# accountOpenDate                      0
# dateOfLastAddressChange              0
# cardLast4Digits                      0
# transactionType                      0
# currentBalance                       0
# cardPresent                          0
# expirationDateKeyInMatch             0
# isFraud                              0
# matchCVV                             0
# accountAge                           0
# sinceDateOfLastAddressChange         0
# monthsToExpiration                   0
# transactionMonth                     0
# transactionDay                       0
# transactionHour                      0
# transactionWeekday                   0
# time_of_day                          0
# is_peak_hour                         0
# is_weekend                           0
# transaction_time_diff                0
# min_time_diff_month                  0
# avgFraud                             0
# customer_fraud_flag                  0
# relative_amount                      0
# rolling_min_month                    0
# rolling_max_month                    0
# rolling_mean_month                   0
# rolling_std_month                    0
# transaction_rolling_diff             0
# is_outlier_customer                  0
# merchant_rolling_min_month           0
# merchant_rolling_max_month           0
# merchant_rolling_mean_month          0
# merchant_rolling_std_month           0
# merchant_transaction_rolling_diff    0
# is_outlier_merchant                  0
# MerchantavgFraud                     0
# merchant_transaction_count           0
# unique_merchants                     0
# customer_merchant_count              0
# rare_interaction                     0
# is_missing_flag                      0
# dtype: int64

# %% [markdown]
# # Saving

# %%
print(df.info())  # Display DataFrame info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740001 entries, 530787 to 750392
# Data columns (total 54 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   customerId                         740001 non-null  int64
#  1   creditLimit                        740001 non-null  int64
#  2   availableMoney                     740001 non-null  float64
#  3   transactionDateTime                740001 non-null  datetime64[ns]
#  4   transactionAmount                  740001 non-null  float64
#  5   merchantName                       740001 non-null  object
#  6   acqCountry                         740001 non-null  object
#  7   merchantCountryCode                740001 non-null  object
#  8   posEntryMode                       740001 non-null  object
#  9   posConditionCode                   740001 non-null  object
#  10  merchantCategoryCode               740001 non-null  object
#  11  currentExpDate                     740001 non-null  datetime64[ns]
#  12  accountOpenDate                    740001 non-null  datetime64[ns]
#  13  dateOfLastAddressChange            740001 non-null  datetime64[ns]
#  14  cardLast4Digits                    740001 non-null  int64
#  15  transactionType                    740001 non-null  object
#  16  currentBalance                     740001 non-null  float64
#  17  cardPresent                        740001 non-null  bool
#  18  expirationDateKeyInMatch           740001 non-null  bool
#  19  isFraud                            740001 non-null  bool
#  20  matchCVV                           740001 non-null  bool
#  21  accountAge                         740001 non-null  int64
#  22  sinceDateOfLastAddressChange       740001 non-null  int64
#  23  monthsToExpiration                 740001 non-null  int32
#  24  transactionMonth                   740001 non-null  int32
#  25  transactionDay                     740001 non-null  int32
#  26  transactionHour                    740001 non-null  int32
#  27  transactionWeekday                 740001 non-null  int32
#  28  time_of_day                        740001 non-null  object
#  29  is_peak_hour                       740001 non-null  bool
#  30  is_weekend                         740001 non-null  bool
#  31  transaction_time_diff              740001 non-null  float64
#  32  min_time_diff_month                740001 non-null  float64
#  33  avgFraud                           740001 non-null  float64
#  34  customer_fraud_flag                740001 non-null  bool
#  35  relative_amount                    740001 non-null  float64
#  36  rolling_min_month                  740001 non-null  float64
#  37  rolling_max_month                  740001 non-null  float64
#  38  rolling_mean_month                 740001 non-null  float64
#  39  rolling_std_month                  740001 non-null  float64
#  40  transaction_rolling_diff           740001 non-null  float64
#  41  is_outlier_customer                740001 non-null  bool
#  42  merchant_rolling_min_month         740001 non-null  float64
#  43  merchant_rolling_max_month         740001 non-null  float64
#  44  merchant_rolling_mean_month        740001 non-null  float64
#  45  merchant_rolling_std_month         740001 non-null  float64
#  46  merchant_transaction_rolling_diff  740001 non-null  float64
#  47  is_outlier_merchant                740001 non-null  bool
#  48  MerchantavgFraud                   740001 non-null  float64
#  49  merchant_transaction_count         740001 non-null  int64
#  50  unique_merchants                   740001 non-null  int64
#  51  customer_merchant_count            740001 non-null  int64
#  52  rare_interaction                   740001 non-null  bool
#  53  is_missing_flag                    740001 non-null  bool
# dtypes: bool(11), datetime64[ns](4), float64(18), int32(5), int64(8), object(8)
# memory usage: 242.1+ MB
# None

# %%
# Saves types to load quickly
df.dtypes.to_csv("transactions_features_dtypes.csv")
# Save data
df.to_parquet('transactions_features.parquet', engine='pyarrow')
